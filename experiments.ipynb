# %%
class experiment:

    def __init__(self):
        print("this is from init")
    def __str__(self):
        print("this is from str")
        return "str method called"
    def __repr__(self):
        print("this is from repr")
        return "repr method called"

# %%
obj = experiment()
# Out:
# this is from init

# %%
print(obj)
# Out:
# this is from str
# str method called

# %%
obj
# Out:
# this is from repr
# repr method called
